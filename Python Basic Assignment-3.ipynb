# %%
Q1.  Why are functions advantageous to have in your programs?
Ans- Reusability, easy debugging, easy understanding, easy enhancment to existiting code are some of the main advantageous of        functions

Q2.  When does the code in a function run: when it's specified or when it's called?
Ans- When function is called, then only it will be executed.

Q3-  What statement creates a function?
Ans- The def statement defines a function
     syntax- def function_name(formal arguments):
             function_body
             
Q4-  What is the difference between a function and a function call?
Ans- A function is procedure to achieve a particular result. while function call is using this function to achive that task.                  def Fun_name(formal arguments):   # define function
                function_body
                 return

             Fun_name(actual arguments)  # call
             
Q5-  How many global scopes are there in a Python program? How many local scopes?
Ans- One global and local scope there in Python.

Q6-   What happens to variables in a local scope when the function call returns?
Ans-  Local scope variable are not available or get destroyed after call returns.

Q7-   What is the concept of a return value? Is it possible to have a return value in an expression?
Ans-  When return executed, program execution control goes back to main control from where the function called. 
     It is possible to return single or multiple values.
     
Q8-  If a function does not have a return statement, what is the return value of a call to that function?
Ans- Nothing / none.
     
Q9-   How do you make a function variable refer to the global variable?
Ans-   A global statement will force a variable in a function to refer to the global variable. If you want to refer to a global       variable in a function, you can use the global keyword to declare which variables are global.
       
           x =10
        def global():
            global x   #use global keyword
            x =11
             print(x)
            global()
            
Q10-  What is the data type of None?
Ans-  The data type of None is NoneType

Q11- What does the sentence import areallyourpetsnamederic do?
Ans- It is a way of making all contents ofanother module available to current program module.

Q12- If you had a bacon() feature in a spam module, what would you call it after importing spam?
Ans- import spam
     spam.bacon()
    
Q13- What can you do to save a programme from crashing if it encounters an error?
Ans- Use try except block.( Place the line of code that might cause an error in a try clause and use except block to handle the      error.
                          ) 
Q14- What is the purpose of the try clause? What is the purpose of the except clause?
Ans- Error causing statement is in try block and if any error happens then execute except block.
